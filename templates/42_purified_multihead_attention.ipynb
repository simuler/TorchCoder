# %% [markdown]
# # HA-LoRA 多头注意力
#
# 实现带 Head-Aware LoRA 与头门控的多头自注意力。
#
# ### Signature
# ```python
# class PurifiedMultiHeadAttention(nn.Module):
# ```
#
# ### 提示
# - 为每个注意力头分别设置低秩 A/B，并用 softmax 门控调节每个头的 LoRA 更新；基础 Q/K/V/O 投影保持标准 MHA。

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math

class PurifiedMultiHeadAttention(nn.Module):
    def __init__(self, d_model: int, num_heads: int, rank: int = 8, alpha: float = 1.0):
        super().__init__()
        # TODO: 在这里实现

    def forward(self, x: torch.Tensor, mask=None):
        pass  # 请在这里补全
