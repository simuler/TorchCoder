# %% [markdown]
# # 手写交叉熵损失
#
# 不调用 `F.cross_entropy`，从 logits 和类别索引手写数值稳定的交叉熵。
#
# ### Signature
# ```python
# def manual_cross_entropy(logits: torch.Tensor, targets: torch.Tensor) -> torch.Tensor:
# ```
#
# ### 提示
# - 先减去每行最大值，用 LogSumExp 得到稳定的 log-softmax，再 gather 目标类别并取负均值。

# %%
import torch

def manual_cross_entropy(logits: torch.Tensor, targets: torch.Tensor) -> torch.Tensor:
    # TODO: 在这里实现
    pass
